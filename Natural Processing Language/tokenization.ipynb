# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in e:\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: click in e:\anaconda\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in e:\anaconda\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in e:\anaconda\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in e:\anaconda\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in e:\anaconda\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk

# Download tokenizer data
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\enggm\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\enggm\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
corpus="""
Machine Learning is a branch of Artificial Intelligence.
It enables computers to learn from data.
Machine learning is used in many applications."""

# %%
### converting paragraph to sentence
from nltk.tokenize import sent_tokenize

# %%
sentences = sent_tokenize(corpus)
print(sentences
     ### or you can use this directly  <sent_tokenize(corpus)>
# Out:
# ['\nMachine Learning is a branch of Artificial Intelligence.', 'It enables computers to learn from data.', 'Machine learning is used in many applications.']

# %%
### or you can use this directly
sent_tokenize(corpus)
# Out:
# ['\nMachine Learning is a branch of Artificial Intelligence.',
#  'It enables computers to learn from data.',
#  'Machine learning is used in many applications.']

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Machine',
#  'Learning',
#  'is',
#  'a',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  '.',
#  'It',
#  'enables',
#  'computers',
#  'to',
#  'learn',
#  'from',
#  'data',
#  '.',
#  'Machine',
#  'learning',
#  'is',
#  'used',
#  'in',
#  'many',
#  'applications',
#  '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Machine',
#  'Learning',
#  'is',
#  'a',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  '.',
#  'It',
#  'enables',
#  'computers',
#  'to',
#  'learn',
#  'from',
#  'data',
#  '.',
#  'Machine',
#  'learning',
#  'is',
#  'used',
#  'in',
#  'many',
#  'applications',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Machine',
#  'Learning',
#  'is',
#  'a',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence.',
#  'It',
#  'enables',
#  'computers',
#  'to',
#  'learn',
#  'from',
#  'data.',
#  'Machine',
#  'learning',
#  'is',
#  'used',
#  'in',
#  'many',
#  'applications',
#  '.']
